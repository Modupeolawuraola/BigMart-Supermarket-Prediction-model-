# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/HP/Desktop/Datasets folder/bigmart_sales.csv')

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df['Outlet_Size'].isnull().sum()
# Out:
# 2410

# %%
#replacing zero and nan values with the mean 
df['Item_Weight'].fillna(value=df['Item_Weight'].mean(), inplace=True)

# %%
#dropping the null values in Outlet 
#df.dropna(subset=['Outlet_Size'], inplace=True)

# %%
#fillining the outlet size with mode values 
mode = df['Outlet_Size'].mode()[0]
df['Outlet_Size'].fillna(mode, inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df.shape
# Out:
# (8523, 12)

# %%
from matplotlib import pyplot
from pandas import read_csv

df.plot(kind='box', layout=(4, 5), subplots=True, sharex=False, sharey=False)
plt.gcf().set_size_inches(20, 20)
pyplot.show()

# %%
#treating the outliers  
df['Item_Visibility']=df['Item_Visibility'].clip(lower=df['Item_Visibility'].quantile(0.05), 
                                                 upper=df['Item_Visibility'].quantile(0.95))

df['Item_Outlet_Sales']=df['Item_Outlet_Sales'].clip(lower=df['Item_Outlet_Sales'].clip(lower=df['Item_Outlet_Sales'].quantile(0.10),
                                                                                       upper=df['Item_Outlet_Sales'].quantile(0.90)))

# %%
from matplotlib import pyplot
from pandas import read_csv

df.plot(kind='box', layout=(4, 5), subplots=True, sharex=False, sharey=False)
plt.gcf().set_size_inches(20, 20)
pyplot.show()

# %% [markdown]
# # DATA EXPLORATION AND ANALYSIS

# %%
#checking distribution for nurical datas 
#this outlet sales shows its not normally distributed 
sns.distplot(df['Item_Outlet_Sales']) #distplot used to check the distribution of a univariate data  for item-outlet-sales
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
sns.displot(df['Item_Outlet_Sales'], kde=False, bins=25)#this shows histogram showing where most of our total bill data lies 
#which is between 0 to 2000

# %%
#joint plot is used to comnined bivirate two distribution point -- to chck certain trends 
sns.jointplot(data=df, x='Item_Weight', y='Item_Visibility')  #do weight of item makes our item visible 
#--- no trends  between item weight and  item visibility ; therefore weight doesent makes our item visible

# %%
#checking for iteam visibility and item sales -- do item visibilty helps increase sales  
sns.jointplot(data=df, x='Item_Visibility', y='Item_Outlet_Sales', kind='reg') 
#this shows low item visibility has high sales ---showing the regression line move towards downward direction  
#no positive trend between item visiblity and sales

# %%
sns.barplot(data=df, x='Outlet_Location_Type', y='Item_Outlet_Sales')
#seen that tier 2 has higher item outlet sales thasn tier 3 and tier1
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.pairplot(data=df, hue='Outlet_Size')
#showing our data overview y=using outlet sieze id its high, low or medium

# %%
#for categorical data 
sns.countplot(data=df, x='Outlet_Size')
#seen here that medium has the highest, follow by small then lastly high
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %%
df['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
sns.boxplot(data=df, x='Outlet_Type', y='Item_Outlet_Sales')
#we can see that supermarket type 3 has higher item outlet sales than supermarket type 1 and 2 , with the gorcery store
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.barplot(data=df, x='Outlet_Identifier', y='Item_Outlet_Sales')
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# # Feature Selection and Feature Engineering

# %%
df.describe().T
# Out:
#                             count         mean          std        min  \
# Item_Weight                8523.0    12.857645     4.226124     4.5550
# Item_Visibility            8523.0     0.064353     0.046606     0.0000
# Item_MRP                   8523.0   140.992782    62.275067    31.2900
# Outlet_Establishment_Year  8523.0  1997.831867     8.371760  1985.0000
# Item_Outlet_Sales          8523.0  2196.319683  1689.295559   343.5528
#
#                                    25%          50%          75%          max
# Item_Weight                   9.310000    12.857645    16.000000     21.35000
# Item_Visibility               0.026989     0.053931     0.094585      0.16378
# Item_MRP                     93.826500   143.012800   185.643700    266.88840
# Outlet_Establishment_Year  1987.000000  1999.000000  2004.000000   2009.00000
# Item_Outlet_Sales           834.247400  1794.331000  3101.296400  13086.96480

# %%
#checking forScaling of the data 
#item weight - min -4 and max - 21( far ; therefor its need rescaling)
#item visisbility min-0 and 0.3( not to far from each other)
#item MPR- 31 and max 266 so therefore its need to be rescale 

#checking for Standardization 
#item weight 4.22 std is far from the mean which is 12( therefore its need tio be restandardize)
#item visisbility std and mean isnt too far from each pother and the 50% to the mean its nkt far
#item MPR std(62) is far from the mean(140) therefor its need to be restardardize

# %%
#cheching for normalization of the data 

df['Item_Outlet_Sales'].plot(kind='density')
#this is skweed to the right ; therefore its has to be rerstandardize
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#checking for normalizattion of item  weight dataset 
#this is not normally distributed - therefor its has to be re-normalized 
df['Item_Weight'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#checking for normalization of item visibility 
#tis shows its skeeded to the left - its has to be renormalized 
df['Item_Visibility'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Doing Rescaling- Standardarization {normalization}

# %%
df.describe().T

# %%
#Resclaing
from sklearn.preprocessing import MinMaxScaler
from numpy import set_printoptions

X= df[['Item_Weight', 'Item_Visibility', 'Item_MRP']]
y= df['Item_Outlet_Sales']
 
scaler= MinMaxScaler(feature_range=(0,1))
rescaleX= scaler.fit_transform(X)

#setting option 

set_printoptions(precision=3)

rescaleX
# Out:
# array([[0.283, 0.098, 0.928],
#        [0.081, 0.118, 0.072],
#        [0.771, 0.102, 0.468],
#        ...,
#        [0.36 , 0.215, 0.228],
#        [0.158, 0.887, 0.305],
#        [0.61 , 0.274, 0.188]])

# %%
#converting back to dataframe and adding item outlet sales 
rescaleXDF= pd.DataFrame(rescaleX, columns=['Item_Weight', 'Item_Visibility', 'Item_MRP'])

print(rescaleXDF)
                                             
#adding back the item outlets sales 

rescaleXDF['Item_Outlet_Sales'] = df['Item_Outlet_Sales']
                                            
print(rescaleXDF)
# Out:
#       Item_Weight  Item_Visibility  Item_MRP
# 0        0.282525         0.097981  0.927507
# 1        0.081274         0.117708  0.072068
# 2        0.770765         0.102333  0.468288
# 3        0.871986         0.000000  0.640093
# 4        0.260494         0.000000  0.095805
# ...           ...              ...       ...
# 8518     0.137541         0.346706  0.777729
# 8519     0.227746         0.286863  0.326263
# 8520     0.359929         0.214839  0.228492
# 8521     0.158083         0.886682  0.304939
# 8522     0.610003         0.274016  0.187510
#
# [8523 rows x 3 columns]
#       Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0        0.282525         0.097981  0.927507          3735.1380
# 1        0.081274         0.117708  0.072068           443.4228
# 2        0.770765         0.102333  0.468288          2097.2700
# 3        0.871986         0.000000  0.640093           732.3800
# 4        0.260494         0.000000  0.095805           994.7052
# ...

# %%
#checking if its has been rescaled 
rescaleXDF.describe().T
# Out:
#                     count         mean          std       min         25%  \
# Item_Weight        8523.0     0.494352     0.251630    0.0000    0.283120
# Item_Visibility    8523.0     0.392926     0.284564    0.0000    0.164791
# Item_MRP           8523.0     0.465635     0.264327    0.0000    0.265437
# Item_Outlet_Sales  8523.0  2196.319683  1689.295559  343.5528  834.247400
#
#                            50%          75%         max
# Item_Weight           0.494352     0.681453      1.0000
# Item_Visibility       0.329289     0.577515      1.0000
# Item_MRP              0.474209     0.655156      1.0000
# Item_Outlet_Sales  1794.331000  3101.296400  13086.9648

# %%
#re-standardization 

X= rescaleXDF[['Item_Weight', 'Item_Visibility', 'Item_MRP']]
y= rescaleXDF['Item_Outlet_Sales']
               
from sklearn.preprocessing import StandardScaler
from numpy import set_printoptions
               
scaler1= StandardScaler().fit(X)
reStandardX= scaler1.transform(X)
    

#setting options 
set_printoptions(precision=3)
               
print(reStandardX)
# Out:
# [[-0.842 -1.037  1.747]
#  [-1.642 -0.967 -1.489]
#  [ 1.099 -1.021  0.01 ]
#  ...
#  [-0.534 -0.626 -0.897]
#  [-1.336  1.735 -0.608]
#  [ 0.46  -0.418 -1.052]]

# %%
#converting it to Dataframe and adding  the sales 
reStandardXDF=pd.DataFrame(reStandardX, columns=('Item_Weight', 'Item_Visibility', 'Item_MRP'))

print(reStandardXDF)

#addingOutlet total sales 
reStandardXDF['Item_Outlet_Sales']=rescaleXDF['Item_Outlet_Sales']

print(reStandardXDF)
# Out:
#       Item_Weight  Item_Visibility  Item_MRP
# 0       -0.841872        -1.036539  1.747454
# 1       -1.641706        -0.967211 -1.489023
# 2        1.098554        -1.021244  0.010040
# 3        1.500838        -1.380878  0.660050
# 4       -0.929428        -1.380878 -1.399220
# ...           ...              ...       ...
# 8518    -1.418084        -0.162433  1.180783
# 8519    -1.059578        -0.372739 -0.527301
# 8520    -0.534243        -0.625859 -0.897208
# 8521    -1.336444         1.735235 -0.607977
# 8522     0.459634        -0.417890 -1.052261
#
# [8523 rows x 3 columns]
#       Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0       -0.841872        -1.036539  1.747454          3735.1380
# 1       -1.641706        -0.967211 -1.489023           443.4228
# 2        1.098554        -1.021244  0.010040          2097.2700
# 3        1.500838        -1.380878  0.660050           732.3800
# 4       -0.929428        -1.380878 -1.399220           994.7052
# ...

# %%
reStandardXDF.describe().T
# Out:
#                     count          mean          std         min         25%  \
# Item_Weight        8523.0  3.534464e-16     1.000059   -1.964716   -0.839505
# Item_Visibility    8523.0 -8.694337e-17     1.000059   -1.380878   -0.801744
# Item_MRP           8523.0 -1.302881e-16     1.000059   -1.761688   -0.757431
# Item_Outlet_Sales  8523.0  2.196320e+03  1689.295559  343.552800  834.247400
#
#                             50%          75%           max
# Item_Weight        4.015271e-14     0.743598      2.009608
# Item_Visibility   -2.236399e-01     0.648713      2.133473
# Item_MRP           3.243893e-02     0.717037      2.021724
# Item_Outlet_Sales  1.794331e+03  3101.296400  13086.964800

# %%
#Doing normalization on the dataset 
from sklearn.preprocessing import Normalizer
from numpy import set_printoptions

X =reStandardXDF[['Item_Weight', 'Item_Visibility', 'Item_MRP']]
y=reStandardXDF['Item_Outlet_Sales']

scaler2= Normalizer().fit(X)
reNomralizeX= scaler2.transform(X)

#setting precision 
set_printoptions(precision=(3))

print(reNomralizeX)
# Out:
# [[-0.383 -0.471  0.795]
#  [-0.679 -0.4   -0.616]
#  [ 0.732 -0.681  0.007]
#  ...
#  [-0.439 -0.514 -0.737]
#  [-0.588  0.763 -0.267]
#  [ 0.376 -0.342 -0.861]]

# %%
#converting to Dataframe and adding outelt sales 

reNomralizeXDF= pd.DataFrame(reNomralizeX, columns= ('Item_Weight', 'Item_Visibility', 'Item_MRP'))

print(reNomralizeXDF)
#adding back the sales 
reNomralizeXDF['Item_Outlet_Sales'] = reStandardXDF['Item_Outlet_Sales']

print(reNomralizeXDF)
# Out:
#       Item_Weight  Item_Visibility  Item_MRP
# 0       -0.382797        -0.471312  0.794564
# 1       -0.678885        -0.399965 -0.615747
# 2        0.732392        -0.680850  0.006694
# 3        0.700150        -0.644188  0.307917
# 4       -0.427420        -0.635031 -0.643466
# ...           ...              ...       ...
# 8518    -0.765515        -0.087685  0.637415
# 8519    -0.853919        -0.300393 -0.424955
# 8520    -0.438834        -0.514089 -0.736978
# 8521    -0.587952         0.763395 -0.267472
# 8522     0.376149        -0.341988 -0.861137
#
# [8523 rows x 3 columns]
#       Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0       -0.382797        -0.471312  0.794564          3735.1380
# 1       -0.678885        -0.399965 -0.615747           443.4228
# 2        0.732392        -0.680850  0.006694          2097.2700
# 3        0.700150        -0.644188  0.307917           732.3800
# 4       -0.427420        -0.635031 -0.643466           994.7052
# ...

# %%
reNomralizeXDF.describe().T
# Out:
#                     count         mean          std         min         25%  \
# Item_Weight        8523.0    -0.006338     0.566129   -0.999242   -0.519557
# Item_Visibility    8523.0    -0.055011     0.574052   -0.999999   -0.532789
# Item_MRP           8523.0    -0.003278     0.589069   -0.999980   -0.527157
# Item_Outlet_Sales  8523.0  2196.319683  1689.295559  343.552800  834.247400
#
#                             50%          75%           max
# Item_Weight        2.706396e-14     0.499704      0.997733
# Item_Visibility   -1.761829e-01     0.455746      0.999990
# Item_MRP           2.412245e-02     0.524063      1.000000
# Item_Outlet_Sales  1.794331e+03  3101.296400  13086.964800

# %% [markdown]
# BEFORE NORMALIZATION

# %%
df['Item_Weight'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# AFTER NORMALIZATION

# %%
reNomralizeXDF['Item_Weight'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# BEFORE NORMALIZATION

# %%
df['Item_Visibility'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# AFTER NORMALIZATION N

# %%
reNomralizeXDF['Item_Visibility'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# BEFORE NORMALIZATION

# %%
df['Item_MRP'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# AFTER NORMALIZATION

# %%
reNomralizeXDF['Item_MRP'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#checking corr 
sns.heatmap(reNomralizeXDF.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#checking correlation between Item-weight and outlet sales
sns.lmplot(data=reNomralizeXDF, x='Item_Weight', y='Item_Outlet_Sales')  #no correlatiobn between the price and outlet sales

# %%
sns.lmplot(data=reNomralizeXDF, x='Item_Visibility', y='Item_Outlet_Sales')

# %% [markdown]
# # ENCODING CATEGORICAL VARIABLE

# %%
df['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
df['Item_Identifier'].unique()
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCF55', 'NCW30', 'NCW05'],
#       dtype=object)

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
df['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
#using label encoding 

encodeList=['Item_Identifier', 'Outlet_Identifier','Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

from sklearn.preprocessing import LabelEncoder

enCode=LabelEncoder()
for x in encodeList:
    df[x]=enCode.fit_transform(df[x])

# %%
df[encodeList]
# Out:
#       Item_Identifier  Outlet_Identifier  Item_Fat_Content  Item_Type  \
# 0                 156                  9                 1          4
# 1                   8                  3                 2         14
# 2                 662                  9                 1         10
# 3                1121                  0                 2          6
# 4                1297                  1                 1          9
# ...               ...                ...               ...        ...
# 8518              370                  1                 1         13
# 8519              897                  7                 2          0
# 8520             1357                  6                 1          8
# 8521              681                  3                 2         13
# 8522               50                  8                 1         14
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               1                     0            1
# ...

# %%
P=df[encodeList]

# %%
#Adding establish year to P 
P['Outlet_Establishment_Year']= df['Outlet_Establishment_Year']
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_1912/1613062407.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   P['Outlet_Establishment_Year']= df['Outlet_Establishment_Year']

# %%
P
# Out:
#       Item_Identifier  Outlet_Identifier  Item_Fat_Content  Item_Type  \
# 0                 156                  9                 1          4
# 1                   8                  3                 2         14
# 2                 662                  9                 1         10
# 3                1121                  0                 2          6
# 4                1297                  1                 1          9
# ...               ...                ...               ...        ...
# 8518              370                  1                 1         13
# 8519              897                  7                 2          0
# 8520             1357                  6                 1          8
# 8521              681                  3                 2         13
# 8522               50                  8                 1         14
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0               1                     0            1
# ...

# %%
reNomralizeXDF
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0       -0.382797        -0.471312  0.794564          3735.1380
# 1       -0.678885        -0.399965 -0.615747           443.4228
# 2        0.732392        -0.680850  0.006694          2097.2700
# 3        0.700150        -0.644188  0.307917           732.3800
# 4       -0.427420        -0.635031 -0.643466           994.7052
# ...           ...              ...       ...                ...
# 8518    -0.765515        -0.087685  0.637415          2778.3834
# 8519    -0.853919        -0.300393 -0.424955           549.2850
# 8520    -0.438834        -0.514089 -0.736978          1193.1136
# 8521    -0.587952         0.763395 -0.267472          1845.5976
# 8522     0.376149        -0.341988 -0.861137           765.6700
#
# [8523 rows x 4 columns]

# %%
#joining the two table 
for x in reNomralizeXDF.columns:
    P[x]=reNomralizeXDF[x]
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_1912/635335163.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   P[x]=reNomralizeXDF[x]

# %%
P
# Out:
#       Item_Identifier  Outlet_Identifier  Item_Fat_Content  Item_Type  \
# 0                 156                  9                 1          4
# 1                   8                  3                 2         14
# 2                 662                  9                 1         10
# 3                1121                  0                 2          6
# 4                1297                  1                 1          9
# ...               ...                ...               ...        ...
# 8518              370                  1                 1         13
# 8519              897                  7                 2          0
# 8520             1357                  6                 1          8
# 8521              681                  3                 2         13
# 8522               50                  8                 1         14
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0               1                     0            1
# ...

# %%
P.shape
# Out:
# (8523, 12)

# %%
#P.drop(['Item_Identifier', 'Outlet_Identifier'], axis=1, inplace=True)

# %%
P
# Out:
#       Item_Identifier  Outlet_Identifier  Item_Fat_Content  Item_Type  \
# 0                 156                  9                 1          4
# 1                   8                  3                 2         14
# 2                 662                  9                 1         10
# 3                1121                  0                 2          6
# 4                1297                  1                 1          9
# ...               ...                ...               ...        ...
# 8518              370                  1                 1         13
# 8519              897                  7                 2          0
# 8520             1357                  6                 1          8
# 8521              681                  3                 2         13
# 8522               50                  8                 1         14
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0               1                     0            1
# ...

# %% [markdown]
# # USING SKLERAN TO TRAIN OUR MODEL

# %%
P.columns
# Out:
# Index(['Item_Identifier', 'Outlet_Identifier', 'Item_Fat_Content', 'Item_Type',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Outlet_Establishment_Year', 'Item_Weight', 'Item_Visibility',
#        'Item_MRP', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# # ASSINGING features to X and Y

# %%
X=P[['Item_Fat_Content', 'Item_Type','Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'Item_Weight',
       'Item_Visibility', 'Item_MRP']]
y=P['Item_Outlet_Sales']

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print(X_train.head())
# Out:
#       Item_Fat_Content  Item_Type  Outlet_Size  Outlet_Location_Type  \
# 1945                 0          9            1                     2
# 1720                 1          9            1                     2
# 1954                 2          6            1                     1
# 1919                 1         13            1                     2
# 2461                 2          6            2                     1
#
#       Outlet_Type  Item_Weight  Item_Visibility  Item_MRP
# 1945            2     0.798935         0.329649  0.503025
# 1720            2     0.433892         0.870787  0.231231
# 1954            1    -0.428181        -0.147356  0.891598
# 1919            2    -0.211781         0.942668 -0.257928
# 2461            1    -0.990299        -0.073203 -0.118110

# %% [markdown]
# # Creating and Train Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.score(X_train, y_train)  #47percent virance of indpendent virable was able to explain the dependent virable , 
#there is still significant amount unexplain
# Out:
# 0.4751054850389267

# %%
lm.score(X_test, y_test)
# Out:
# 0.48255374490299674

# %% [markdown]
# # Model Evaluation

# %%
print(lm.intercept_)
# Out:
# 1756.6593199785807

# %%
#printing coffient 
lm.coef_
# Out:
# array([ 3.537e+01,  5.599e-01, -3.019e+02, -3.898e+02,  9.764e+02,
#         1.340e+01, -1.072e+02,  1.576e+03])

# %%
#checking traing columns 
X_train.columns
# Out:
# Index(['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Weight', 'Item_Visibility', 'Item_MRP'],
#       dtype='object')

# %%
cdf=pd.DataFrame(lm.coef_, X_train.columns, columns=['Coefficient'])

# %%
cdf
# Out:
#                       Coefficient
# Item_Fat_Content        35.370045
# Item_Type                0.559943
# Outlet_Size           -301.879419
# Outlet_Location_Type  -389.789068
# Outlet_Type            976.360865
# Item_Weight             13.402085
# Item_Visibility       -107.192059
# Item_MRP              1575.684090

# %% [markdown]
# # Prediction of the Model

# %%
Predictions= lm.predict(X_test)

# %%
Predictions
# Out:
# array([ 536.735, 1150.005, 3002.244, ..., 2476.551, 2184.29 , 1762.063])

# %%
y_test
# Out:
# 1070     952.7598
# 6305    1133.8574
# 8504    4138.6128
# 5562    1657.1762
# 1410     679.1160
#           ...
# 376     5715.2272
# 7708    4832.3764
# 3812    2972.1312
# 3928    2492.7552
# 7654    1717.7640
# Name: Item_Outlet_Sales, Length: 1705, dtype: float64

# %%
#comparing prediction go y_test 
print(Predictions, y_test)
# Out:
# [ 536.735 1150.005 3002.244 ... 2476.551 2184.29  1762.063] 1070     952.7598
# 6305    1133.8574
# 8504    4138.6128
# 5562    1657.1762
# 1410     679.1160
#           ...
# 376     5715.2272
# 7708    4832.3764
# 3812    2972.1312
# 3928    2492.7552
# 7654    1717.7640
# Name: Item_Outlet_Sales, Length: 1705, dtype: float64

# %% [markdown]
# # Another way of comparing original sales  to the predicted car price is by doing scatter plot

# %%
plt.scatter(y_test, Predictions)

# %%
#Creating Residual Histogram between y-test and prediction 
sns.distplot(y_test-Predictions)
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %% [markdown]
# # Calculating Evaluation Metrics

# %%
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
metrics.mean_absolute_error(y_test, Predictions)
# Out:
# 925.172164010064

# %%
metrics.mean_squared_error(y_test, Predictions)
# Out:
# 1500964.2422810944

# %%
np.sqrt(metrics.mean_squared_error(y_test, Predictions))
# Out:
# 1225.1384584123928

# %%
np.mean(y_train)
# Out:
# 2206.2219494866386

# %%
r2=(r2_score(y_test, Predictions))

print("R-square error: {:.2f}".format(r2)) ##An R-squared value of 0.48 indicates that 48% of the variance in the 
#dependent variable is explained by the independent variable(s) used in the linear regression model.
#In other words, the independent variable(s) used in the model can explain 48% of the variation in the dependent variable.
# Out:
# R-square error: 0.48

# %% [markdown]
# THIS MODEL CAN BE IMPROVED BY TESTING IT ON ANOTHER ALGORITHMS LIKE RANDOM FOREST, DICISION TREE OR NUERAL NETWORK
